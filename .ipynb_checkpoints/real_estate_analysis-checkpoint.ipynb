# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import pymongo
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import json
plt.style.use('seaborn')
from sklearn.linear_model import LinearRegression

# %%
from scipy.stats import pearsonr, ttest_ind, zscore
from statsmodels.stats import weightstats as stests
import folium
from folium.plugins import MarkerCluster, HeatMap

# %%
#import data from mongodb
client = pymongo.MongoClient()
db = client.austinhomes
collection = db.clean_home_data
aus_home_df = pd.DataFrame(list(collection.find()))

# %%
#view count of samples by source
zillow_df = aus_home_df.query("source == 'zillow'")
realtor_df = aus_home_df.query("source == 'reator'")
austin_realty_df = aus_home_df.query("source == 'austin_realty'")

# %%
print('Austin Realty Count: {:,.0f}'.format(len(austin_realty_df)))
print('Realtor Count: {:,.0f}'.format(len(realtor_df)))
print('Zillow Count: {:,.0f}'.format(len(zillow_df)))
# Out:
# Austin Realty Count: 2,791
# Realtor Count: 1,714
# Zillow Count: 2,143

# %%
#dropping all duplicates listings from the different websites (zillow, realtor, austin realty)
aus_home_df['address'] = aus_home_df['address'].apply(lambda x: x.lower())
#assigned to new dataframe
working_df = aus_home_df.drop_duplicates('address')

# %%
#overview analysis 
working_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4920 entries, 0 to 6645
# Data columns (total 12 columns):
# _id          4920 non-null object
# address      4920 non-null object
# baths        4920 non-null float64
# beds         4917 non-null float64
# cost         4920 non-null float64
# sq_ft        4920 non-null float64
# data_type    4920 non-null object
# city         4920 non-null object
# zip          4920 non-null int64
# source       4920 non-null object
# lat          4920 non-null float64
# lon          4920 non-null float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 499.7+ KB

# %%
#inspect missing data
working_df.query("beds == 'nan'")
# Out:
#                            _id                         address  baths  beds  \
# 1451  5e1509d3708b1eed4f3b9f7e              44 east ave  #2206    1.0   NaN
# 1803  5e1509d3708b1eed4f3ba0e1           2213 poquito st  #115    1.0   NaN
# 2585  5e1509d4708b1eed4f3ba3f0   1600 barton springs rd  #5208    1.0   NaN
#
#           cost  sq_ft    data_type    city    zip         source        lat  \
# 1451  330000.0  481.0  Residential  Austin  78701  austin_realty  30.256205
# 1803  175000.0  407.0  Residential  Austin  78722  austin_realty  30.283748
# 2585  400000.0  743.0  Residential  Austin  78704  austin_realty  30.263106
#
#             lon
# 1451 -97.738787
# 1803 -97.720670
# 2585 -97.760989

# %%
#updated missing data values 
working_df.loc[:,'beds'].fillna(0, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
#viewed type of home in my dataframe
working_df['data_type'].value_counts()
# Out:
# Residential                  2738
# House for Sale               1252
# House for sale                367
# Condo/Townhome                331
# Condo for sale                107
# For sale by owner              36
# Mfd/Mobile Home                29
# Multi-Family Home              25
# Coming soon                    15
# Pre-foreclosure / Auction       7
# Townhouse for sale              7
# Home for sale                   2
# Auction                         2
# Apartment for sale              1
# Foreclosure                     1
# Name: data_type, dtype: int64

# %%
working_df.describe()
# Out:
#              baths         beds          cost         sq_ft           zip  \
# count  4920.000000  4920.000000  4.920000e+03   4920.000000   4920.000000
# mean      2.791463     3.251220  6.847894e+05   2242.950610  78731.714228
# std       1.246466     1.129138  1.003589e+06   1401.570268     19.190564
# min       1.000000     0.000000  3.000000e+04    289.000000  78652.000000
# 25%       2.000000     3.000000  3.224750e+05   1373.750000  78721.000000
# 50%       3.000000     3.000000  4.405000e+05   1927.000000  78737.000000
# 75%       3.000000     4.000000  6.550000e+05   2744.000000  78746.000000
# max      13.000000    24.000000  3.500000e+07  20708.000000  78759.000000
#
#                lat          lon
# count  4920.000000  4920.000000
# mean     30.288045   -97.782459
# std       0.085910     0.101221
# min      30.104571   -98.050622
# 25%      30.226018   -97.836209
# 50%      30.280400   -97.760356
# 75%      30.347210   -97.718291
# max      30.520579   -97.521809

# %%
#filtered out data, not corresponding the statistical test of equal-ratio v unequal-ratio homes
w_df = working_df.query("data_type != ['Foreclosure', 'Apartment for sale', 'Auction', 'Pre-foreclosure / Auction','Mfd/Mobile Home']" )
w_df.loc[:,'zip'] = w_df.loc[:,'zip'].astype('category')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
w_df.describe()
# Out:
#              baths         beds          cost         sq_ft          lat  \
# count  4880.000000  4880.000000  4.880000e+03   4880.000000  4880.000000
# mean      2.796824     3.250615  6.887889e+05   2248.567008    30.287762
# std       1.248307     1.132220  1.006571e+06   1405.514953     0.085853
# min       1.000000     0.000000  3.000000e+04    289.000000    30.104571
# 25%       2.000000     3.000000  3.249000e+05   1375.000000    30.225988
# 50%       3.000000     3.000000  4.459525e+05   1931.000000    30.280030
# 75%       3.000000     4.000000  6.610000e+05   2763.000000    30.346886
# max      13.000000    24.000000  3.500000e+07  20708.000000    30.520579
#
#                lon
# count  4880.000000
# mean    -97.782914
# std       0.101050
# min     -98.050622
# 25%     -97.836401
# 50%     -97.760367
# 75%     -97.718804
# max     -97.521809

# %%
w_df['source'].value_counts()
# Out:
# austin_realty    2738
# reator           1608
# zillow            534
# Name: source, dtype: int64

# %%
def central_tendency_by(attr, data, sort='count', asc=False): 
    '''
    Groups data by the attribute chosen and generates central tendency outputs of cost, beds,
    baths, and sq_ft.
    
    Parameters:
    -----------
    attr (str): Attribute to be grouped by
    data (dataframe): Dataframe to be analyzed 
    sort (str): Sigle or list of attributes to be sorted by, optional
    asc (bool): True or False, optional
    
    Returns:
    --------
    Series or DataFrame:
        Summary statistics median, mean, count, mean_beds, mean_baths, mean_sqft.  
    '''
    
    grouped = data.groupby(str(attr))
    ct = pd.DataFrame({'median':grouped['cost'].median().apply(lambda x : "{:,.2f}".format(x)),
                           'mean':grouped['cost'].mean().apply(lambda x : "{:,.2f}".format(x)),
                           'count':grouped['cost'].count(),
                            'mean_beds':grouped['beds'].mean().apply(lambda x: "{:1.0f}".format(x)),
                            'mean_baths':grouped['baths'].mean().apply(lambda x: "{:1.0f}".format(x)),
                            'mean_sqft':round(grouped['sq_ft'].mean())
                           })
    return ct.sort_values(sort, ascending=asc)

# %%
grp_zip_df = central_tendency_by('zip', w_df)
grp_zip_df.head()
# Out:
#            median        mean  count mean_beds mean_baths  mean_sqft
# zip
# 78704  715,000.00  889,501.39    355         3          3     1893.0
# 78745  361,425.00  388,753.95    275         3          2     1517.0
# 78737  527,990.00  614,659.86    259         4          3     3150.0
# 78738  612,900.00  793,224.55    256         4          4     3485.0
# 78748  315,000.00  327,912.17    213         3          3     1952.0

# %%
mod_df.to_csv('modified_data.csv', index=False)

# %%
#scatter plot with and pearsonr correlation between square feet and value of home
def plot_jointplot(data, x='sq_ft', y='cost', kind='reg', height=12, yunit='thousands'):
    '''
    Creates joint plot with histogram, distribution, scatter plot, and provides a pearsonr line
    
    Parameters:
    -----------
    data (dataframe): data to be used for plotting
    x (str): series for the x-axis, set to 'sq_ft'
    y (str): series for the y-axis, set to 'cost'
    kind: set to 'reg'
    height: set to 12
    yunit: set to 'thousands'
    
    Returns:
    --------
    Returns a seaborn jointplot graph 
    '''
    sns.jointplot(x=x, y=y, kind=kind, data=data, height=(height), stat_func=pearsonr)
    plt.ylabel(f'price of homes in {yunit} of dollars ($)')
    plt.xlabel('square feet of homes')
    plt.title('Sample Analysis of {} and {}'.format(x, y), fontsize=20)
    plt.savefig('../images/jointplot.png')
    return plt.show()


plot_jointplot(w_df, yunit='millions')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-202-5fe77342ca6a> in <module>
#      25
#      26
# ---> 27 plot_jointplot(w_df, yunit='millions')
#
# <ipython-input-202-5fe77342ca6a> in plot_jointplot(data, x, y, kind, height, yunit)
#      21     plt.xlabel('square feet of homes')
#      22     plt.title('Sample Analysis of {} and {}'.format(x, y), fontsize=20)
# ---> 23     plt.savefig('../images/jointplot.png')
#      24     return plt.show()
#      25
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# /opt/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../images/jointplot.png'

# %%
#derive outliers for any particular parameter
def outliers(data, column):
    '''
    Derives the interquartile range (IQR) for a dataset parameter. And 
    
    Parameters:
    -----------
    data (dataframe): Dataframe to be analyzed
    column (str): Name of parameter (column) for quantile analysis 
    
    Returns:
    --------
    Two values (int): upper and lower outlier limits. 
    '''
    
    Q1_cost = data[str(column)].quantile(.25) 
    Q3_cost = data[str(column)].quantile(.75) 
    
    IQR = Q3_cost - Q1_cost
    
    upper_limit_outlier = Q3_cost + (1.5*IQR)
    lower_limit_outlier = Q1_cost - (1.5*IQR)
    return upper_limit_outlier, lower_limit_outlier

# %%
#derived outlier limits
cost_ol = outliers(w_df, 'cost')
sqft_ol = outliers(w_df, 'sq_ft')
print(cost_ol, sqft_ol)

# %%
#removed outliers
mod_df = w_df.query("cost < 1165150.0 and sq_ft < 4845.0")
mod_df.describe()

# %%
#scatter plot with and pearsonr correlation between square feet and value of home
plot_jointplot(mod_df)

# %% [markdown]
# ### Is there a statistically significant difference in the value of homes between equal bed-to-bath ratio vs unequal ratio homes.
# Ho: mean of two groups is 0<br>
# H1: mean of two groups is not 0
#
# Ho: The null hypothesis is that the ratio of bedroom to bathroom ratio has not affect on the mean value of a home.<br>
# H1: The alternative hypothesis is that the ration of the home has an affect.

# %%
#splitting data without outliers
equal_ratio = mod_df.query("beds == baths")
unequal_ratio = mod_df.query("beds != baths")

#splitting data with outliers
org_equal_ratio = w_df.query("beds == baths")
org_unequal_ratio = w_df.query("beds != baths")

print("Original Data Equal-Ratio v Unequal-Ratio Avg Home Value: {:,.0f} | {:,.0f}"
      .format(np.mean(org_equal_ratio['cost']), np.mean(org_unequal_ratio['cost'])))
print("Adjusted Data Equal-Ratio v Unequal-Ratio Avg Home Value: {:,.0f} | {:,.0f}"
      .format(np.mean(equal_ratio['cost']), np.mean(unequal_ratio['cost'])))
print("Adjusted Equal count: {:,.0f} | Adjusted Unequal Count: {:,.0f}".format(len(equal_ratio), len(unequal_ratio)))
print("Average difference of: {:,.0f}".format(np.mean(equal_ratio['cost'])-np.mean(unequal_ratio['cost'])))

# %%
print("Total Sample Sq-Ft Mean: {:,.0f}".format(round(np.mean(mod_df['sq_ft'])))) 
print("Equal Ratio Sq-Ft Mean: {:,.0f}".format(round(np.mean(equal_ratio['sq_ft'])))) 
print("Unequal Ratio Sq-Ft Mean: {:,.0f}".format(round(np.mean(unequal_ratio['sq_ft']))))
# Out:
# Total Sample Sq-Ft Mean: 1,948
# Equal Ratio Sq-Ft Mean: 1,796
# Unequal Ratio Sq-Ft Mean: 2,023

# %%
#distributions of equal and unequal samples
fig, ax = plt.subplots(figsize=(16,9))
ax_eq =sns.kdeplot(equal_ratio['cost'], shade=True, label='Equal Ratio | Mean: {:5,.0f}'.format(np.mean(equal_ratio['cost'])))
ax_un =sns.kdeplot(unequal_ratio['cost'], shade=True, label='Unequal Ratio | Mean: {:5,.0f}'.format(np.mean(unequal_ratio['cost'])))

#plotting averages of samples
ax_eq.axvline(np.mean(equal_ratio['cost']), color='blue',alpha=0.6)
ax_un.axvline(np.mean(unequal_ratio['cost']), color='green', alpha=0.6)

ax.set_xlabel('Value of Home')
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter(''))
ax.legend(fancybox=True, shadow=True, borderpad=1, framealpha=1, frameon=True, fontsize=16)

plt.title('Shaded Density Plot of Equal v Unequal Ratio Homes in Austin, TX', fontsize=25)
plt.savefig('../images/distributions.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-204-6f8156eb331a> in <module>
#      14
#      15 plt.title('Shaded Density Plot of Equal v Unequal Ratio Homes in Austin, TX', fontsize=25)
# ---> 16 plt.savefig('../images/distributions.png')
#      17 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# /opt/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../images/distributions.png'

# %% [markdown]
# ### Why use a z-test
#
# A z-test is a statistical test used to determine whether two population means are different when the variances are known and the sample size is large.
#
# 1) Your sample size is > 30<br>
# 2) Data points should be independent from each other, one point does not affect another data point<br>
# 3) It can be used to test hypotheses in which the z-test follows a normal distribution<br>
# 4) Data needs to be randomly selected from the population, where each item has an equal chance of being selected<br>
# 5) A z-statistic, or z-score, is a number representing the result from the z-test

# %%
print("1) Adjusted Equal Count: {:,.0f} | Adjusted Unequal Count: {:,.0f}".format(len(equal_ratio), len(unequal_ratio)))
# Out:
# 1) Adjusted Equal Count: 1,424 | Adjusted Unequal Count: 2,894

# %%
#z-test analysis
ztest, pval = stests.ztest(equal_ratio['cost'], unequal_ratio['cost'], alternative='two-sided', ddof=1)

if pval < 0.05:
    print('The p-value of {:2.3f} is smaller than 0.05 we reject null hypothesis'.format(pval))
else:
    print('The p-value of {:2.3f} is greater than 0.05 so we fail to reject the null hypothesis'.format(pval))
    
print('z-score: {:2.3f}, p-value: {:2.3f}'.format(ztest,pval))
# Out:
# The p-value of 0.001 is smaller than 0.05 we reject null hypothesis
# z-score: 3.386, p-value: 0.001

# %%
#plot zscore
fig, ax = plt.subplots(figsize=(16,9))

#obtaining the zscores for both equal and unequal
ax_eq = sns.kdeplot(zscore(equal_ratio['cost']))
ax_un =sns.kdeplot(zscore(unequal_ratio['cost']))

#plotting averages of samples
ax_eq.axvline(ztest, color='teal',alpha=0.6, linestyle='--',  label='z-score of {:.3f}'.format(ztest))

ax.set_title('Density Plot and Z-score of Equal v Unequal Ratio Homes in Austin, TX', fontsize=25)
ax.legend(fancybox=True, shadow=True, borderpad=1, framealpha=1, frameon=True, fontsize=16)

plt.savefig('../images/z-score.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-207-4eb8a77db174> in <module>
#      12 ax.legend(fancybox=True, shadow=True, borderpad=1, framealpha=1, frameon=True, fontsize=16)
#      13
# ---> 14 plt.savefig('../images/z-score.png')
#      15 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# /opt/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../images/z-score.png'

# %% [markdown]
# There is enough data to deduce that equal ratio homes tend to be worth more than unequal ratio homes by an average of $22,000.

# %%
mlr = LinearRegression()

X, y = mod_df[['beds', 'baths', 'sq_ft']], mod_df['cost']
mlr.fit(X,y)

#difference between y to the mean of y
yhat=mlr.predict(X)
SS_Residual= sum((y-yhat)**2)

#sum of square total: measurment of total variability in variable y
SS_Total = sum((y-np.mean(y))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1-(1-r_squared)*(len(y)-1)/(len(y)-X.shape[1]-1)

print("R^2: {:2.2f}, Adj_R^2: {:2.2f}".format(r_squared,adjusted_r_squared))
# Out:
# R^2: 0.31, Adj_R^2: 0.31

# %%
mlr = LinearRegression()

#created dummie variables for zipcodes
test_df = pd.get_dummies(mod_df, columns=['zip'], drop_first=True)

cols = ['_id', 'address', 'cost', 'data_type', 'city', 'source', 'lat', 'lon']
X = test_df.drop(cols, axis=1)
y = test_df['cost']
mlr.fit(X,y)

#difference between y to the mean of y
yhat=mlr.predict(X)
SS_Residual= sum((y-yhat)**2)

#sum of square total: measurment of total variability in variable y
SS_Total = sum((y-np.mean(y))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1-(1-r_squared)*(len(y)-1)/(len(y)-X.shape[1]-1)

print("R^2: {:2.2f}, Adj_R^2: {:2.2f}".format(r_squared,adjusted_r_squared))
# Out:
# R^2: 0.69, Adj_R^2: 0.69

# %%
corr_matrix = mod_df[['baths', 'beds', 'cost', 'sq_ft']].corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d1e4b054_33c5_11ea_aed0_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row0_col1 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row0_col2 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row0_col3 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row1_col0 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row1_col3 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row3_col0 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row3_col1 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row3_col2 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_d1e4b054_33c5_11ea_aed0_acde48001122row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_d1e4b054_33c5_11ea_aed0_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >baths</th>        <th class="col_heading level0 col1" >beds</th>        <th class="col_heading level0 col2" >cost</th>        <th class="col_heading level0 col3" >sq_ft</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d1e4b054_33c5_11ea_aed0_acde48001122level0_row0" class="row_heading level0 row0" >baths</th>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row0_col1" class="data row0 col1" >0.643641</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row0_col2" class="data row0 col2" >0.46997</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row0_col3" class="data row0 col3" >0.768284</td>
#             </tr>
#             <tr>
#                         <th id="T_d1e4b054_33c5_11ea_aed0_acde48001122level0_row1" class="row_heading level0 row1" >beds</th>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row1_col0" class="data row1 col0" >0.643641</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row1_col2" class="data row1 col2" >0.33075</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row1_col3" class="data row1 col3" >0.745301</td>
#             </tr>
#             <tr>
#                         <th id="T_d1e4b054_33c5_11ea_aed0_acde48001122level0_row2" class="row_heading level0 row2" >cost</th>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row2_col0" class="data row2 col0" >0.46997</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row2_col1" class="data row2 col1" >0.33075</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row2_col3" class="data row2 col3" >0.533204</td>
#             </tr>
#             <tr>
#                         <th id="T_d1e4b054_33c5_11ea_aed0_acde48001122level0_row3" class="row_heading level0 row3" >sq_ft</th>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row3_col0" class="data row3 col0" >0.768284</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row3_col1" class="data row3 col1" >0.745301</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row3_col2" class="data row3 col2" >0.533204</td>
#                         <td id="T_d1e4b054_33c5_11ea_aed0_acde48001122row3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>

# %%
sns.pairplot(mod_df[['baths', 'beds', 'cost', 'sq_ft']])
plt.savefig('../images/correlation_plots.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-211-232d2d0dc6b1> in <module>
#       1 sns.pairplot(mod_df[['baths', 'beds', 'cost', 'sq_ft']])
# ----> 2 plt.savefig('../images/correlation_plots.png')
#       3 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# /opt/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../images/correlation_plots.png'

# %%
#displaying bed, bath, and zip counts within my sample
fig, ax = plt.subplots(3,1, figsize=(12,18))
sns.countplot(mod_df['beds'], ax=ax[0])
sns.countplot(mod_df['baths'], ax=ax[1])
sns.countplot(mod_df['zip'], ax=ax[2], order = mod_df['zip'].value_counts().index)
ax[2].set_xticklabels(ax[2].get_xticklabels(), rotation=50, ha="right")

plt.title('Number of homes by categories: Beds, Baths, Zipcode')
ax[0].set_ylabel('number of homes')
ax[1].set_ylabel('number of homes')
ax[2].set_ylabel('number of homes')
plt.savefig('../images/count_tables.png')
plt.show()

# %%
#create a new column with bed and bath to be able to do a groupby base on unique ratios
mod_df.loc[:,'beds_baths'] = mod_df.loc[:,'beds'].map(str) + ' x ' + mod_df.loc[:,'baths'].map(str)

# %%
fig, ax = plt.subplots(figsize=(18,9))
sns.countplot(mod_df['beds_baths'], order = mod_df['beds_baths'].value_counts().index)
ax.set_xticklabels(ax.get_xticklabels(), rotation=50, ha="right")
ax.set_title('Austin Home Market Room to Bath Ratio Count', fontsize=25)
ax.set_ylabel('Count of Homes')
ax.set_xlabel('Home type by bed x bath ratio')
plt.savefig('../images/bed_bath_ratio_count.png')
plt.show()

# %%
beds_bath_df = central_tendency_by('beds_baths', mod_df, sort='count') 
beds_bath_df.head()

# %%
map_df = mod_df[['cost','source','lat','lon']]
# sub_setmap = map_df.query("source == 'reator'")
sub_setmap = map_df[:2000]
austin_map = folium.Map(location=['30.264980', '-97.746597'], zoom_start =10)

mc = MarkerCluster()

for row in sub_setmap.itertuples():
    mc.add_child(folium.Marker(location=[row.lat,row.lon], popup=[row.cost]))

# %%
map_df = mod_df[['cost','source','lat','lon']]
sub_setmap = map_df
austin_map = folium.Map(location=['30.264980', '-97.746597'], zoom_start=11)
HeatMap(data=sub_setmap[['lat', 'lon']].values.tolist(), radius=9, max_zoom=13).add_to(austin_map)
# austin_map
austin_map.add_child(mc)

# %% [markdown]
# Limitations:
#
# Square feet only take into account size of the livable space.  It does not take into account actual bath or bedroom sizes.
#
# This is sample size of the current market over a one month span.
#
# Looking forward:
#
# Incorporate more data to help improve the R^2.  Enrich the dataset by continue to run scrapers over a 12 month-period.  Bring historic data to see if the aggregate value shifted at any point and derive by how much.

# %% [markdown]
# Methodology:
# Data used in the study included square footage, number of beds, baths, and value for all single and multi-family homes, condo, and townhomes with active listings in the Austin housing market from December 2019 to January 2020, inside the city limits.  This data was used to calculate averages and test for significance between equal ratio vs unequal ratio homes. All figures shown in the article represent the mean value for each data point unless otherwise specified. The IQR (interquartile range) method of outlier detection was implemented as part of the data cleansing process.
